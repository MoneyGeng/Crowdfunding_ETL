# %% [markdown]
# <a href="https://colab.research.google.com/github/MoneyGeng/Crowdfunding_ETL/blob/main/SQL_ETL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#imports
import psycopg2
import pandas as pd
import numpy as np
from pylab import rcParams
import warnings
import itertools
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')
import statsmodels.api as sm
import matplotlib
import statsmodels.api as sm
from scipy.stats import linregress

matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'

# %%
# Establish a connection to psycopg
conn = psycopg2.connect(
    host="containers-us-west-196.railway.app",
    port="7781",
    database="railway",
    user="postgres",
    password="EP8JoJQ90wOswb54Tny0")

# %%
# Execute a query and fetch all rows from a table
query = "SELECT * FROM pearson"
df_pearson = pd.read_sql(query, conn)
# Display the retrieved data
df_pearson
# Out:
#       id month  year mean_temp date_time
# 0      1   JAN  1937             1937-01
# 1      2   FEB  1937             1937-02
# 2      3   MAR  1937             1937-03
# 3      4   APR  1937             1937-04
# 4      5   MAY  1937             1937-05
# ..   ...   ...   ...       ...       ...
# 913  914   FEB  2013      -4.6   2013-02
# 914  915   MAR  2013       0.1   2013-03
# 915  916   APR  2013       6.0   2013-04
# 916  917   MAY  2013      15.2   2013-05
# 917  918   JUN  2013      16.5   2013-06
#
# [918 rows x 5 columns]

# %%
# Execute a query and fetch all rows from a table
query = "SELECT * FROM billybishop"
df_billybishop = pd.read_sql(query, conn)
# Display the retrieved data
df_billybishop
# Out:
#         id month  year mean_temp date_time
# 0        1   JAN  1840             1840-01
# 1        2   FEB  1840             1840-02
# 2        3   MAR  1840       1.2   1840-03
# 3        4   APR  1840       6.7   1840-04
# 4        5   MAY  1840      12.4   1840-05
# ...    ...   ...   ...       ...       ...
# 1999  2000   AUG  2006             2006-08
# 2000  2001   SEP  2006             2006-09
# 2001  2002   OCT  2006             2006-10
# 2002  2003   NOV  2006             2006-11
# 2003  2004   DEC  2006             2006-12
#
# [2004 rows x 5 columns]

# %%
# Execute a query and fetch all rows from a table
query = "SELECT * FROM buttonville"
df_buttonville = pd.read_sql(query, conn)
# Display the retrieved data
df_buttonville
# Out:
#       id month  year mean_temp date_time
# 0      1   JAN  1986             1986-01
# 1      2   FEB  1986             1986-02
# 2      3   MAR  1986             1986-03
# 3      4   APR  1986             1986-04
# 4      5   MAY  1986             1986-05
# ..   ...   ...   ...       ...       ...
# 348  349   JAN  2015      -8.1   2015-01
# 349  350   FEB  2015     -13.3   2015-02
# 350  351   MAR  2015      -2.5   2015-03
# 351  352   APR  2015       7.2   2015-04
# 352  353   MAY  2015      15.6   2015-05
#
# [353 rows x 5 columns]

# %%
# Concatenate the three dataframes (df_pearson, df_buttonville, df_billybishop) into a single dataframe
# The ignore_index=True parameter resets the index of the concatenated dataframe
concatenated_df = pd.concat([df_pearson, df_buttonville, df_billybishop], ignore_index=True)
concatenated_df
# Out:
#         id month  year mean_temp date_time
# 0        1   JAN  1937             1937-01
# 1        2   FEB  1937             1937-02
# 2        3   MAR  1937             1937-03
# 3        4   APR  1937             1937-04
# 4        5   MAY  1937             1937-05
# ...    ...   ...   ...       ...       ...
# 3270  2000   AUG  2006             2006-08
# 3271  2001   SEP  2006             2006-09
# 3272  2002   OCT  2006             2006-10
# 3273  2003   NOV  2006             2006-11
# 3274  2004   DEC  2006             2006-12
#
# [3275 rows x 5 columns]

# %%
# Close the database connection
conn.close()

# %%
concatenated_df
# Out:
#         id month  year mean_temp date_time
# 0        1   JAN  1937       NaN   1937-01
# 1        2   FEB  1937       NaN   1937-02
# 2        3   MAR  1937       NaN   1937-03
# 3        4   APR  1937       NaN   1937-04
# 4        5   MAY  1937       NaN   1937-05
# ...    ...   ...   ...       ...       ...
# 3270  2000   AUG  2006       NaN   2006-08
# 3271  2001   SEP  2006       NaN   2006-09
# 3272  2002   OCT  2006       NaN   2006-10
# 3273  2003   NOV  2006       NaN   2006-11
# 3274  2004   DEC  2006       NaN   2006-12
#
# [3275 rows x 5 columns]

# %%
# Replace empty strings with NaN
concatenated_df['mean_temp'] = concatenated_df['mean_temp'].replace('', np.nan)

# Dropping null values 
cleaned_df = concatenated_df.dropna()
cleaned_df
# Out:
#         id month  year mean_temp date_time
# 10      11   NOV  1937       3.3   1937-11
# 11      12   DEC  1937      -4.4   1937-12
# 12      13   JAN  1938      -7.2   1938-01
# 13      14   FEB  1938      -3.7   1938-02
# 14      15   MAR  1938       1.4   1938-03
# ...    ...   ...   ...       ...       ...
# 3228  1958   FEB  2003      -5.1   2003-02
# 3229  1959   MAR  2003       0.9   2003-03
# 3230  1960   APR  2003       6.2   2003-04
# 3231  1961   MAY  2003      13.1   2003-05
# 3232  1962   JUN  2003      18.7   2003-06
#
# [3212 rows x 5 columns]

# %%
# Convert the column to float
cleaned_df['mean_temp'] = cleaned_df['mean_temp'].astype(float)

# Convert the date_time column to datetime
cleaned_df['date_time'] = pd.to_datetime(cleaned_df['date_time'], format='%Y-%m')

# Convert the year column to int (useful later on for ML)
cleaned_df['year'] = cleaned_df['year'].astype(int)

# checking changes have been made
cleaned_df.dtypes
# Out:
# id                    int64
# month                object
# year                  int64
# mean_temp           float64
# date_time    datetime64[ns]
# dtype: object

# %%
# Group the cleaned_df dataframe by the columns ['year', 'month', 'date_time'] and calculate the mean of the 'mean_temp' column for each group
average_df = cleaned_df.groupby(['year', 'month', 'date_time'])['mean_temp'].mean().reset_index()

# Display the first 20 rows of the mean_df dataframe
average_df.head(24)
# Out:
#     year month  date_time  mean_temp
# 0   1840   APR 1840-04-01        6.7
# 1   1840   AUG 1840-08-01       19.0
# 2   1840   DEC 1840-12-01       -4.9
# 3   1840   JUL 1840-07-01       19.5
# 4   1840   JUN 1840-06-01       15.8
# 5   1840   MAR 1840-03-01        1.2
# 6   1840   MAY 1840-05-01       12.4
# 7   1840   NOV 1840-11-01        2.1
# 8   1840   OCT 1840-10-01        7.4
# 9   1840   SEP 1840-09-01       12.6
# 10  1841   APR 1841-04-01        4.3
# 11  1841   AUG 1841-08-01       18.7
# 12  1841   DEC 1841-12-01       -2.0
# 13  1841   FEB 1841-02-01       -5.5
# 14  1841   JAN 1841-01-01       -4.5
# 15  1841   JUL 1841-07-01       19.2
# 16  1841   JUN 1841-06-01       19.4
# 17  1841   MAR 1841-03-01       -2.3
# 18  1841   MAY 1841-05-01       11.0
# 19  1841   NOV 1841-11-01        1.3
# 20  1841   OCT 1841-10-01        5.7
# 21  1841   SEP 1841-09-01       16.1
# 22  1842   APR 1842-04-01        7.0
# 23  1842   AUG 1842-08-01       19.5

# %%
# Sort df by date_time and reset index
average_df.sort_values('date_time', ascending = True, inplace = True)
average_df.reset_index(inplace=True)
average_df
# Out:
#       index  year month  date_time  mean_temp
# 0         5  1840   MAR 1840-03-01        1.2
# 1         0  1840   APR 1840-04-01        6.7
# 2         6  1840   MAY 1840-05-01       12.4
# 3         4  1840   JUN 1840-06-01       15.8
# 4         3  1840   JUL 1840-07-01       19.5
# ...     ...   ...   ...        ...        ...
# 2098   2100  2015   JAN 2015-01-01       -8.1
# 2099   2099  2015   FEB 2015-02-01      -13.3
# 2100   2101  2015   MAR 2015-03-01       -2.5
# 2101   2098  2015   APR 2015-04-01        7.2
# 2102   2102  2015   MAY 2015-05-01       15.6
#
# [2103 rows x 5 columns]

# %%
#Save dataframe to csv file 
average_df.to_csv('mean_temperature.csv')

# %%
# Create a dictory that maps that month names to the month numbers 
month_map = {'JAN': 1,
             'FEB': 2,
             'MAR': 3,
             'APR': 4,
             'MAY': 5,
             'JUN': 6,
             'JUL': 7,
             'AUG': 8 ,
             'SEP': 9 ,
             'OCT': 10,
             'NOV': 11,
             'DEC' :12}

average_df['month'] = average_df['month'].map(month_map)

average_df.head(5)
# Out:
#    index  year  month  date_time  mean_temp
# 0      5  1840      3 1840-03-01        1.2
# 1      0  1840      4 1840-04-01        6.7
# 2      6  1840      5 1840-05-01       12.4
# 3      4  1840      6 1840-06-01       15.8
# 4      3  1840      7 1840-07-01       19.5

# %% [markdown]
# #time series model

# %%
average_df.dtypes
# Out:
# index                 int64
# year                  int64
# month                 int64
# date_time    datetime64[ns]
# mean_temp           float64
# dtype: object

# %% [markdown]
# **Data Preprocessing**
#
# This steps includes removing the columns year, and month, which are not needed. Setting the date_time timeline that you would like to use to base the model off and sorting the date in descending order for date_time. Next you index the time-series data so that it starts at the first of each month.

# %%
# make a copy of the dataset
series = average_df[['date_time', 'mean_temp']].copy()
series
# Out:
#       date_time  mean_temp
# 0    1840-03-01        1.2
# 1    1840-04-01        6.7
# 2    1840-05-01       12.4
# 3    1840-06-01       15.8
# 4    1840-07-01       19.5
# ...         ...        ...
# 2098 2015-01-01       -8.1
# 2099 2015-02-01      -13.3
# 2100 2015-03-01       -2.5
# 2101 2015-04-01        7.2
# 2102 2015-05-01       15.6
#
# [2103 rows x 2 columns]

# %%
series = series_sorted_descending = series.sort_values('date_time')
series
# Out:
#       date_time  mean_temp
# 0    1840-03-01        1.2
# 1    1840-04-01        6.7
# 2    1840-05-01       12.4
# 3    1840-06-01       15.8
# 4    1840-07-01       19.5
# ...         ...        ...
# 2098 2015-01-01       -8.1
# 2099 2015-02-01      -13.3
# 2100 2015-03-01       -2.5
# 2101 2015-04-01        7.2
# 2102 2015-05-01       15.6
#
# [2103 rows x 2 columns]

# %%
series.dtypes
# Out:
# date_time    datetime64[ns]
# mean_temp           float64
# dtype: object

# %%
series.head(5)
# Out:
#    date_time  mean_temp
# 0 1840-03-01        1.2
# 1 1840-04-01        6.7
# 2 1840-05-01       12.4
# 3 1840-06-01       15.8
# 4 1840-07-01       19.5

# %%
latest_year = series['date_time'].max()
print('most current date:', latest_year)

earliest_year = series['date_time'].min()
print('earliest date:', earliest_year)
# Out:
# most current date: 2015-05-01 00:00:00
# earliest date: 1840-03-01 00:00:00

# %%
series.head()
# Out:
#    date_time  mean_temp
# 0 1840-03-01        1.2
# 1 1840-04-01        6.7
# 2 1840-05-01       12.4
# 3 1840-06-01       15.8
# 4 1840-07-01       19.5

# %%
# Select the subset data from 1900 - 2014
mask = (series['date_time'] >= '1900-01-01') & (series['date_time'] <= '2014-12-01')
series = series.loc[mask]

# Reset the index 
series.set_index("date_time", inplace=True)

series
# Out:
#             mean_temp
# date_time
# 1900-01-01       -3.4
# 1900-02-01       -6.7
# 1900-03-01       -4.8
# 1900-04-01        7.5
# 1900-05-01       12.9
# ...               ...
# 2014-08-01       19.5
# 2014-09-01       15.9
# 2014-10-01       10.4
# 2014-11-01        1.7
# 2014-12-01       -0.6
#
# [1380 rows x 1 columns]

# %%
# To simplify the analysis, instead of using the current datetime data, we will use the average mean temp value for each month, with the timestamp set as the start of each month.
y = series['mean_temp'].resample('MS').mean()

#look at 2014 data
y['2014':]
# Out:
# date_time
# 2014-01-01    -9.3
# 2014-02-01    -9.2
# 2014-03-01    -4.8
# 2014-04-01     5.9
# 2014-05-01    13.9
# 2014-06-01    19.3
# 2014-07-01    19.6
# 2014-08-01    19.5
# 2014-09-01    15.9
# 2014-10-01    10.4
# 2014-11-01     1.7
# 2014-12-01    -0.6
# Freq: MS, Name: mean_temp, dtype: float64

# %% [markdown]
# **Visualizing the Mean Temperature Time Series Data**

# %%
# Apply the Moving Average function by a subset of size 30 days.
temp_df_mean = series.mean_temp.rolling(window=30).mean()
temp_df_mean.plot(figsize=(25,10))
plt.xlabel('Date')
plt.ylabel('Temperature')
plt.title('Mean Temperature')

plt.xticks(rotation=45)
plt.yticks(range(0, 15, 1))
plt.grid(True, linestyle='--', linewidth=0.5, color='gray')
plt.legend(loc='upper right', fontsize='medium')
plt.show()

# %% [markdown]
# When we plot the data, we can observe distinct patterns. The time-series exhibits a seasonality pattern where temperatures are consistently low at the beginning of the year and high in the middle of the year. These recurring patterns provide valuable insights into the temperature trends throughout the year.

# %%
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(y, model='additive')
fig = decomposition.plot()
plt.show()

# %% [markdown]
# We can employ a technique called time-series decomposition to visualize our data. This technique helps us to analyze the individual components of the time series, including trend, seasonality, and noise. By decomposing the time series, we can gain insights into the underlying patterns and fluctuations present in the data. These plot show that the temperature is unstable along the observed seasonality.

# %% [markdown]
# **Deploying the SARIMA Machine Modeling**
#
#
# We will utilize SARIMA, a widely employed method for time-series forecasting. SARIMA stands for Seasonal Autoregressive Integrated Moving Average, and it incorporates seasonality, trend, and noise factors in the data. SARIMA models are represented by the notation SARIMA(p, d, q)(P, D, Q, s), where the parameters p, d, q capture the non-seasonal components, and P, D, Q, s account for the seasonal components. By considering these parameters, SARIMA enables us to effectively model and forecast time-series data.

# %%
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %% [markdown]
# In our time series forecasting analysis, we will employ ARIMA, an extensively utilized method. ARIMA stands for Autoregressive Integrated Moving Average, and it effectively captures seasonality, trend, and noise within the data.
#
# ARIMA models are represented by the notation ARIMA(p, d, q), where the parameters p, d, and q correspond to the autoregressive, integrated, and moving average components, respectively. By incorporating these parameters, ARIMA enables us to effectively model and forecast time series data while considering important characteristics such as seasonality, trend, and noise.

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(y,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)
            results = mod.fit()
            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except Exception as e:
            print('An exception occurred:', e)
            continue
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:10907.668602445772
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:9422.145905583915
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:6475.9437732786555
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:5553.378142549702
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:6466.997912687491
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:5603.708167318994
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:6075.973406707955
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:5554.183318123481
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:9489.790684146416
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:8458.366261357845
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:6407.088971819301
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:5483.246691144503
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:6396.962804104414
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:5617.186477968835
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:6016.963248739614
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:5483.154539678038
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:8567.35253921277
# ARIMA(0, 1, 0)x(0, 0, 1, 12)12 - AIC:7759.67532050128
# ARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:7059.0120179654
# ARIMA(0, 1, 0)x(0, 1, 1, 12)12 - AIC:6116.828062187193
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ARIMA(0, 1, 0)x(1, 0, 0, 12)12 - AIC:6939.271549921597
# ARIMA(0, 1, 0)x(1, 0, 1, 12)12 - AIC:6176.387697565957
# ARIMA(0, 1, 0)x(1, 1, 0, 12)12 - AIC:6671.049957063386
# ARIMA(0, 1, 0)x(1, 1, 1, 12)12 - AIC:6116.916809108412
# ARIMA(0, 1, 1)x(0, 0, 0, 12)12 - AIC:8118.2818256928285
# ARIMA(0, 1, 1)x(0, 0, 1, 12)12 - AIC:7637.556629237769
# ARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:6512.368248291701
# ARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:5510.229174579021
# ARIMA(0, 1, 1)x(1, 0, 0, 12)12 - AIC:6463.274779859194
# ARIMA(0, 1, 1)x(1, 0, 1, 12)12 - AIC:5571.048771576342
# ARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:6094.097600248824
# ARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:5511.6641174391425
# ARIMA(1, 0, 0)x(0, 0, 0, 12)12 - AIC:8509.982881573764
# ARIMA(1, 0, 0)x(0, 0, 1, 12)12 - AIC:7676.56949227658
# ARIMA(1, 0, 0)x(0, 1, 0, 12)12 - AIC:6403.023328362152
# ARIMA(1, 0, 0)x(0, 1, 1, 12)12 - AIC:5475.383887062383
# ARIMA(1, 0, 0)x(1, 0, 0, 12)12 - AIC:6382.456914089306
# ARIMA(1, 0, 0)x(1, 0, 1, 12)12 - AIC:5526.719848689951
# ARIMA(1, 0, 0)x(1, 1, 0, 12)12 - AIC:6005.880277189874
# ARIMA(1, 0, 0)x(1, 1, 1, 12)12 - AIC:5475.85509678101
# ARIMA(1, 0, 1)x(0, 0, 0, 12)12 - AIC:8029.825462734481
# ARIMA(1, 0, 1)x(0, 0, 1, 12)12 - AIC:7529.50122180268
# ARIMA(1, 0, 1)x(0, 1, 0, 12)12 - AIC:6395.104588045029
# ARIMA(1, 0, 1)x(0, 1, 1, 12)12 - AIC:5456.289718415431
# ARIMA(1, 0, 1)x(1, 0, 0, 12)12 - AIC:6377.287295897335
# ARIMA(1, 0, 1)x(1, 0, 1, 12)12 - AIC:5509.490559856082
# ARIMA(1, 0, 1)x(1, 1, 0, 12)12 - AIC:6000.969903766978
# ARIMA(1, 0, 1)x(1, 1, 1, 12)12 - AIC:5457.622592400471
# ARIMA(1, 1, 0)x(0, 0, 0, 12)12 - AIC:7864.791858056271
# ARIMA(1, 1, 0)x(0, 0, 1, 12)12 - AIC:7560.999257701898
# ARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:6806.459491433872
# ARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:5850.439062332221
# ARIMA(1, 1, 0)x(1, 0, 0, 12)12 - AIC:6747.294045195317
# ARIMA(1, 1, 0)x(1, 0, 1, 12)12 - AIC:5908.569279350064
# ARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:6408.067507038108
# ARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:5851.191155871162
# ARIMA(1, 1, 1)x(0, 0, 0, 12)12 - AIC:7861.151703503734
# ARIMA(1, 1, 1)x(0, 0, 1, 12)12 - AIC:7542.159178847924
# ARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:6400.707728777106
# ARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:5466.764798888091
# ARIMA(1, 1, 1)x(1, 0, 0, 12)12 - AIC:6374.395695928056
# ARIMA(1, 1, 1)x(1, 0, 1, 12)12 - AIC:5526.198234680922
# ARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:6010.110810904269
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:5468.7643394179395

# %% [markdown]
# The parameters with the lowest AIC score is ARIMA(1, 0, 1)x(0, 1, 1, 12)12 -  with AIC score of 5456.289718415431

# %% [markdown]
# **Fitting the SARIMA Model**
#
# Running a model diagnostic to investigate any outliners in the dataset. In the normal Q-Q plot, we see that red KDE line follows closely with the N(0,1) normal distribution line. This is a good indication that the results are normally distributed.

# %%
try:
    mod = sm.tsa.statespace.SARIMAX(y,
                                    order=(1, 0, 1),
                                    seasonal_order=(0, 1, 1, 12),
                                    enforce_stationarity=False,
                                    enforce_invertibility=False)
    results = mod.fit()
    print(results.summary().tables[1])
except Exception as e:
    print('An exception occurred:', e)
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7154      0.064     11.184      0.000       0.590       0.841
# ma.L1         -0.5271      0.077     -6.861      0.000      -0.678      -0.376
# ma.S.L12      -1.0160      0.011    -94.928      0.000      -1.037      -0.995
# sigma2         3.0948      0.113     27.380      0.000       2.873       3.316
# ==============================================================================

# %%
results.plot_diagnostics(figsize=(10, 12))
plt.show()

# %% [markdown]
# **Forecasting the Weather**
#
#
# To initiate the forecasts, the provided code assumes a starting point of January 2013.
#
# By setting the dynamic parameter to False, the code ensures that each forecast is generated based on the entire historical data available up to that specific point. This approach is known as one-step ahead forecasting.
#
# To evaluate the accuracy of our forecasts, we can plot both the actual and predicted values of the average daily temperature. To focus on the latter portion of the time series, we have applied a slicing technique to zoom in on the desired timeframe by modifying the date index.
#
# Overall, our forecasts align with the true values very well, showing a seasonal cycle of length 365 days.

# %%
pred = results.get_prediction(start=pd.to_datetime('2012-01-01'), dynamic=False)
pred_ci = pred.conf_int()
ax = y['2010':].plot(label='Observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(7, 6))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('Temperature (C)')
plt.legend(loc='upper left', fontsize='small')

plt.show()

# %%
y_forecasted = pred.predicted_mean
y_truth = y['2013-01-01':]
mse = ((y_forecasted - y_truth) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 3)))
# Out:
# The Mean Squared Error of our forecasts is 3.235

# %%
print('The Root Mean Squared Error of our forecasts is {}'.format(round(np.sqrt(mse), 3)))
# Out:
# The Root Mean Squared Error of our forecasts is 1.799

# %% [markdown]
# The root mean squared error is as low as 1.8 Which means we are able to predict the future forecast with a better accurancy rate.

# %%
# Set the desired starting index for plotting
start_index = '2010-01-01'

# Subset the data from the desired starting index
subset_data = y[start_index:]

# Generate the forecast
pred_uc = results.get_forecast(steps=100)
pred_ci = pred_uc.conf_int()

# Plot the observed data
ax = subset_data.plot(label='Observed')

# Plot the forecasted data
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')

# Fill the confidence interval
ax.fill_between(pred_ci.index, pred_ci.iloc[:, 0], pred_ci.iloc[:, 1], color='k', alpha=.2)

# Set the x-axis label and y-axis label
ax.set_xlabel('Date')
ax.set_ylabel('Temperature (C)')

# Adjust the x-axis limits for more open space
x_min = subset_data.index.min()
x_max = pred_ci.index[-1]
x_margin = (x_max - x_min) * 0.05
plt.xlim(x_min - x_margin, x_max + x_margin)

ax.set_ylim([-20, 30])
plt.legend()

# Show the plot
plt.show()
